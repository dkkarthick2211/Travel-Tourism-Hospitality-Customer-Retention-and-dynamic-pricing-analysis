# %%
import pandas as pd 
df=pd.read_csv("Hotel-Booking-Dataset-final.csv.csv")

# %%
df=pd.read_csv("Hotel-Booking-Dataset-final.csv.csv")

# %%
df.head()
# Out:
#    booking_id         hotel  lead_time    year     Month   Day  \
# 0      100001    City Hotel      171.0  2023.0  December  19.0
# 1      100002  Resort Hotel      221.0  2024.0    August  23.0
# 2      100003    City Hotel      283.0  2024.0     April  26.0
# 3      100004    City Hotel      166.0  2023.0  November  12.0
# 4      100005    City Hotel      281.0  2025.0   January   7.0
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 0                      4.0                   6.0     2.0       0.0  ...
# 1                      3.0                   4.0     2.0       0.0  ...
# 2                      2.0                   3.0     1.0       2.0  ...
# 3                      4.0                   2.0     3.0       1.0  ...
# 4                      2.0                   2.0     2.0       0.0  ...
#
#    distribution_channel previous_cancellations booking_changes deposit_type  \
# ...

# %%
df.tail()
# Out:
#       booking_id         hotel  lead_time    year      Month   Day  \
# 1995      101996  Resort Hotel      104.0  2024.0  September   9.0
# 1996      101997  Resort Hotel      209.0  2023.0      March   7.0
# 1997      101998    City Hotel      242.0  2025.0    October  16.0
# 1998      101999    City Hotel      270.0  2025.0       June  26.0
# 1999      102000    City Hotel      314.0  2024.0   February  13.0
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 1995                      0.0                   6.0     4.0       1.0  ...
# 1996                      0.0                   1.0     4.0       2.0  ...
# 1997                      2.0                   1.0     2.0       0.0  ...
# 1998                      4.0                   5.0     3.0       1.0  ...
# 1999                      0.0                   3.0     3.0       2.0  ...
#
#       distribution_channel previous_cancellations booking_changes  \
# ...

# %%
df.shape
# Out:
# (2000, 23)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   booking_id                 2000 non-null   int64
#  1   hotel                      1993 non-null   str
#  2   lead_time                  1990 non-null   float64
#  3   year                       1994 non-null   float64
#  4   Month                      1992 non-null   str
#  5   Day                        1993 non-null   float64
#  6   stays_in_weekend_nights    1993 non-null   float64
#  7   stays_in_week_nights       1994 non-null   float64
#  8   adults                     1993 non-null   float64
#  9   children                   1989 non-null   float64
#  10  babies                     1990 non-null   float64
#  11  country                    1990 non-null   str
#  12  market_segment             1989 non-null   str
# ...

# %%
df.describe()
# Out:
#           booking_id    lead_time         year          Day  \
# count    2000.000000  1990.000000  1994.000000  1993.000000
# mean   101000.500000   182.754774  2024.012036    14.353236
# std       577.494589   104.594744     0.822937     8.089898
# min    100001.000000     0.000000  2023.000000     1.000000
# 25%    100500.750000    94.250000  2023.000000     8.000000
# 50%    101000.500000   180.500000  2024.000000    14.000000
# 75%    101500.250000   273.000000  2025.000000    21.000000
# max    102000.000000   365.000000  2025.000000    28.000000
#
#        stays_in_weekend_nights  stays_in_week_nights       adults  \
# count              1993.000000           1994.000000  1993.000000
# mean                  2.017561              3.984955     2.507777
# std                   1.413217              2.007206     1.118961
# min                   0.000000              1.000000     1.000000
# 25%                   1.000000              2.000000     2.000000
# ...

# %%
df.isnull()
# Out:
#       booking_id  hotel  lead_time   year  Month    Day  \
# 0          False  False      False  False  False  False
# 1          False  False      False  False  False  False
# 2          False  False      False  False  False  False
# 3          False  False      False  False  False  False
# 4          False  False      False  False  False  False
# ...          ...    ...        ...    ...    ...    ...
# 1995       False  False      False  False  False  False
# 1996       False  False      False  False  False  False
# 1997       False  False      False  False  False  False
# 1998       False  False      False  False  False  False
# 1999       False  False      False  False  False  False
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 0                       False                 False   False     False  ...
# 1                       False                 False   False     False  ...
# ...

# %%
df.isnull().sum()
# Out:
# booking_id                    0
# hotel                         7
# lead_time                    10
# year                          6
# Month                         8
# Day                           7
# stays_in_weekend_nights       7
# stays_in_week_nights          6
# adults                        7
# children                     11
# babies                       10
# country                      10
# market_segment               11
# distribution_channel          7
# previous_cancellations       10
# booking_changes               9
# deposit_type                  9
# agent                         7
# days_in_waiting_list         12
# customer_type                 3
# average_daily_rate            8
# total_of_special_requests     8
# reservation_status           11
# dtype: int64

# %%
df['lead_time'] = df['lead_time'].fillna(df['lead_time'].median())
df['average_daily_rate'] = df['average_daily_rate'].fillna(df['average_daily_rate'].median())
df['hotel'].fillna(df['hotel'].mode()[0])

# %%
df['year']=df['year'].fillna(df['year'].median())

# %%
df['Day']=df['Day'].fillna(df['Day'].mean())

# %%
df['country']=df['country'].fillna(df['country'].mode()[0])

# %%
df['customer_type']=df['customer_type'].fillna(df['customer_type'].mode()[0])

# %%
df['customer_type']=df['customer_type'].fillna(df['customer_type'].mode()[0])

# %%
df['reservation_status']=df['reservation_status'].fillna(df['reservation_status'].mode()[0])

# %%
df.isnull().sum()
# Out:
# booking_id                    0
# hotel                         7
# lead_time                     0
# year                          0
# Month                         8
# Day                           0
# stays_in_weekend_nights       7
# stays_in_week_nights          6
# adults                        7
# children                      0
# babies                       10
# country                       0
# market_segment               11
# distribution_channel          7
# previous_cancellations       10
# booking_changes               9
# deposit_type                  9
# agent                         7
# days_in_waiting_list         12
# customer_type                 0
# average_daily_rate            0
# total_of_special_requests     8
# reservation_status            0
# dtype: int64

# %%
df.head()
# Out:
#    booking_id         hotel  lead_time    year     Month   Day  \
# 0      100001    City Hotel      171.0  2023.0  December  19.0
# 1      100002  Resort Hotel      221.0  2024.0    August  23.0
# 2      100003    City Hotel      283.0  2024.0     April  26.0
# 3      100004    City Hotel      166.0  2023.0  November  12.0
# 4      100005    City Hotel      281.0  2025.0   January   7.0
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 0                      4.0                   6.0     2.0       0.0  ...
# 1                      3.0                   4.0     2.0       0.0  ...
# 2                      2.0                   3.0     1.0       2.0  ...
# 3                      4.0                   2.0     3.0       1.0  ...
# 4                      2.0                   2.0     2.0       0.0  ...
#
#    distribution_channel previous_cancellations booking_changes deposit_type  \
# ...

# %%
df['lead_time']=df['lead_time'].astype(int)
df['year']=df['year'].astype(int)
df['Day']=df['Day'].astype(int)

# %%
df['adults']=df['adults'].astype('Int64')
df['children']=df['children'].astype('Int64')
df['babies']=df['babies'].astype('Int64')

# %%
df['total_of_special_requests']=df['total_of_special_requests'].astype('Int64')
df['stays_in_weekend_nights']=df['stays_in_weekend_nights'].astype('Int64')

# %%
df['stays_in_week_nights']=df['stays_in_week_nights'].astype('Int64')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   booking_id                 2000 non-null   int64
#  1   hotel                      1993 non-null   str
#  2   lead_time                  2000 non-null   int64
#  3   year                       2000 non-null   int64
#  4   Month                      1992 non-null   str
#  5   Day                        2000 non-null   int64
#  6   stays_in_weekend_nights    1993 non-null   Int64
#  7   stays_in_week_nights       1994 non-null   Int64
#  8   adults                     1993 non-null   Int64
#  9   children                   2000 non-null   Int64
#  10  babies                     1990 non-null   Int64
#  11  country                    2000 non-null   str
#  12  market_segment             1989 non-null   str
#  13  distribution_channel       1993 non-null   str
# ...

# %%
df['agent']=df['agent'].astype('Int64')
df['booking_changes']=df['booking_changes'].astype('Int64')

# %%
df['country'].fillna(df['country'].mode()[0])
df['customer_type'].fillna(df['customer_type'].mode()[0])
# Out:
# 0           Group
# 1       Transient
# 2        Contract
# 3           Group
# 4           Group
#           ...
# 1995        Group
# 1996        Group
# 1997     Contract
# 1998    Transient
# 1999    Transient
# Name: customer_type, Length: 2000, dtype: str

# %%
df['Month'].fillna(df['Month'].mode()[0])
df['reservation_status'].fillna(df['reservation_status'].mode()[0])
# Out:
# 0        Canceled
# 1       Check-Out
# 2        Canceled
# 3       Check-Out
# 4       Check-Out
#           ...
# 1995    Check-Out
# 1996    Check-Out
# 1997    Check-Out
# 1998    Check-Out
# 1999     Canceled
# Name: reservation_status, Length: 2000, dtype: str

# %%
df['hotel'].fillna(df['hotel'].mode()[0])
# Out:
# 0         City Hotel
# 1       Resort Hotel
# 2         City Hotel
# 3         City Hotel
# 4         City Hotel
#             ...
# 1995    Resort Hotel
# 1996    Resort Hotel
# 1997      City Hotel
# 1998      City Hotel
# 1999      City Hotel
# Name: hotel, Length: 2000, dtype: str

# %%
df['market_segment'].fillna(df['market_segment'].mode()[0])
df['distribution_channel'].fillna(df['distribution_channel'].mode()[0])
# Out:
# 0             GDS
# 1           TA/TO
# 2           TA/TO
# 3           TA/TO
# 4       Corporate
#           ...
# 1995    Corporate
# 1996          GDS
# 1997        TA/TO
# 1998        TA/TO
# 1999       Direct
# Name: distribution_channel, Length: 2000, dtype: str

# %%
df['reservation_status'].fillna(df['reservation_status'].mode()[0])
# Out:
# 0        Canceled
# 1       Check-Out
# 2        Canceled
# 3       Check-Out
# 4       Check-Out
#           ...
# 1995    Check-Out
# 1996    Check-Out
# 1997    Check-Out
# 1998    Check-Out
# 1999     Canceled
# Name: reservation_status, Length: 2000, dtype: str

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   booking_id                 2000 non-null   int64
#  1   hotel                      1993 non-null   str
#  2   lead_time                  2000 non-null   int64
#  3   year                       2000 non-null   int64
#  4   Month                      1992 non-null   str
#  5   Day                        2000 non-null   int64
#  6   stays_in_weekend_nights    1993 non-null   Int64
#  7   stays_in_week_nights       1994 non-null   Int64
#  8   adults                     1993 non-null   Int64
#  9   children                   2000 non-null   Int64
#  10  babies                     1990 non-null   Int64
#  11  country                    2000 non-null   str
#  12  market_segment             1989 non-null   str
#  13  distribution_channel       1993 non-null   str
# ...

# %%
df['hotel'].fillna(df['hotel'].mode()[0])
# Out:
# 0         City Hotel
# 1       Resort Hotel
# 2         City Hotel
# 3         City Hotel
# 4         City Hotel
#             ...
# 1995    Resort Hotel
# 1996    Resort Hotel
# 1997      City Hotel
# 1998      City Hotel
# 1999      City Hotel
# Name: hotel, Length: 2000, dtype: str

# %%
df.isnull().sum()
# Out:
# booking_id                    0
# hotel                         7
# lead_time                     0
# year                          0
# Month                         8
# Day                           0
# stays_in_weekend_nights       7
# stays_in_week_nights          6
# adults                        7
# children                      0
# babies                       10
# country                       0
# market_segment               11
# distribution_channel          7
# previous_cancellations       10
# booking_changes               9
# deposit_type                  9
# agent                         7
# days_in_waiting_list         12
# customer_type                 0
# average_daily_rate            0
# total_of_special_requests     8
# reservation_status            0
# dtype: int64

# %%
df['babies'].fillna(df['babies'].mode()[0])
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1995    1
# 1996    0
# 1997    1
# 1998    1
# 1999    0
# Name: babies, Length: 2000, dtype: Int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['babies']=df['babies'].fillna(0)

# %%
df.isnull().sum()
# Out:
# booking_id                    0
# hotel                         7
# lead_time                     0
# year                          0
# Month                         8
# Day                           0
# stays_in_weekend_nights       7
# stays_in_week_nights          6
# adults                        7
# children                      0
# babies                        0
# country                       0
# market_segment               11
# distribution_channel          7
# previous_cancellations       10
# booking_changes               9
# deposit_type                  9
# agent                         7
# days_in_waiting_list         12
# customer_type                 0
# average_daily_rate            0
# total_of_special_requests     8
# reservation_status            0
# dtype: int64

# %%
df['days_in_waiting_list']=df['days_in_waiting_list'].ffill()

# %%
df.head()
# Out:
#    booking_id         hotel  lead_time  year     Month  Day  \
# 0      100001    City Hotel        171  2023  December   19
# 1      100002  Resort Hotel        221  2024    August   23
# 2      100003    City Hotel        283  2024     April   26
# 3      100004    City Hotel        166  2023  November   12
# 4      100005    City Hotel        281  2025   January    7
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 0                        4                     6       2         0  ...
# 1                        3                     4       2         0  ...
# 2                        2                     3       1         2  ...
# 3                        4                     2       3         1  ...
# 4                        2                     2       2         0  ...
#
#    distribution_channel previous_cancellations booking_changes deposit_type  \
# 0                   GDS                    0.0               4   Refundable
# ...

# %%
df['market_segment']=df['market_segment'].bfill()

# %%
df['previous_cancellations']=df['previous_cancellations'].bfill()

# %%
df['total_of_special_requests']=df['total_of_special_requests'].interpolate()

# %%
df['agent']=df['agent'].interpolate()

# %%
df['booking_changes']=df['booking_changes'].interpolate()

# %%
df['stays_in_weekend_nights']=df['stays_in_weekend_nights'].interpolate()
df['stays_in_week_nights']=df['stays_in_week_nights'].interpolate()

# %%
df['deposit_type']=df['deposit_type'].bfill()
df['distribution_channel']=df['distribution_channel'].bfill()
df['adults']=df['adults'].bfill()

# %%
df['Month']=df['Month'].ffill()
df['hotel']=df['hotel'].ffill()

# %%
df.isnull().sum()
# Out:
# booking_id                   0
# hotel                        0
# lead_time                    0
# year                         0
# Month                        0
# Day                          0
# stays_in_weekend_nights      0
# stays_in_week_nights         0
# adults                       0
# children                     0
# babies                       0
# country                      0
# market_segment               0
# distribution_channel         0
# previous_cancellations       0
# booking_changes              0
# deposit_type                 0
# agent                        0
# days_in_waiting_list         0
# customer_type                0
# average_daily_rate           0
# total_of_special_requests    0
# reservation_status           0
# dtype: int64

# %%
import seaborn as sns
sns.boxplot(x=df['average_daily_rate'])
# Out:
# <Axes: xlabel='average_daily_rate'>

# %%
df['total_stay'] = (
    df['stays_in_weekend_nights'] +
    df['stays_in_week_nights']
)

# %%
df['total_stay']
# Out:
# 0       10.0
# 1        7.0
# 2        5.0
# 3        6.0
# 4        4.0
#         ...
# 1995     6.0
# 1996     1.0
# 1997     3.0
# 1998     9.0
# 1999     3.0
# Name: total_stay, Length: 2000, dtype: Float64

# %%
df['total_guests'] = (
    df['adults'] +
    df['children'] +
    df['babies']
)

# %%
df['total_guests']
# Out:
# 0       3
# 1       2
# 2       4
# 3       4
# 4       2
#        ..
# 1995    6
# 1996    6
# 1997    3
# 1998    5
# 1999    5
# Name: total_guests, Length: 2000, dtype: Int64

# %%
df['booking_type'] = df['lead_time'].apply(
    lambda x: 'Early Booking' if x > 90 else 'Last Minute'
)

# %%
df['booking_type']
# Out:
# 0       Early Booking
# 1       Early Booking
# 2       Early Booking
# 3       Early Booking
# 4       Early Booking
#             ...
# 1995    Early Booking
# 1996    Early Booking
# 1997    Early Booking
# 1998    Early Booking
# 1999    Early Booking
# Name: booking_type, Length: 2000, dtype: str
